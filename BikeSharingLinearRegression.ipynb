# %% [markdown]
# ### Bike Sharing Assignment
#
# Linear Regression Assignment - Build a model for prediction of bike rental daily count based on the environmental and seasonal settings.

# %%
import pandas as pd
import os

# Plotting
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Data Dictionary
#
# day.csv have the following fields:
#
# 	- instant: record index
# 	- dteday : date
# 	- season : season (1:spring, 2:summer, 3:fall, 4:winter)
# 	- yr : year (0: 2018, 1:2019)
# 	- mnth : month ( 1 to 12)
# 	- holiday : weather day is a holiday or not (extracted from http://dchr.dc.gov/page/holiday-schedule)
# 	- weekday : day of the week
# 	- workingday : if day is neither weekend nor holiday is 1, otherwise is 0.
# 	+ weathersit :
# 		- 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# 		- 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# 		- 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# 		- 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# 	- temp : temperature in Celsius
# 	- atemp: feeling temperature in Celsius
# 	- hum: humidity
# 	- windspeed: wind speed
# 	- casual: count of casual users
# 	- registered: count of registered users
# 	- cnt: count of total rental bikes including both casual and registered

# %% [markdown]
# ### Download & Load Dataset
#
# Data Dictionary is a csv and accessible with pandas

# %%
df_data = pd.read_csv('day.csv', index_col = 'instant')

# %% [markdown]
# ### Dataset Wrangling
#
# Inspect data types, data size, handle missing values, and more.

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 730 entries, 1 to 730
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dteday      730 non-null    object
#  1   season      730 non-null    int64
#  2   yr          730 non-null    int64
#  3   mnth        730 non-null    int64
#  4   holiday     730 non-null    int64
#  5   weekday     730 non-null    int64
#  6   workingday  730 non-null    int64
#  7   weathersit  730 non-null    int64
#  8   temp        730 non-null    float64
#  9   atemp       730 non-null    float64
#  10  hum         730 non-null    float64
#  11  windspeed   730 non-null    float64
#  12  casual      730 non-null    int64
#  13  registered  730 non-null    int64
#  14  cnt         730 non-null    int64
# dtypes: float64(4), int64(10), object(1)
# memory usage: 91.2+ KB

# %%
df_data.head(5)
# Out:
#              dteday  season  yr  mnth  holiday  weekday  workingday  \
# instant
# 1        01-01-2018       1   0     1        0        6           0
# 2        02-01-2018       1   0     1        0        0           0
# 3        03-01-2018       1   0     1        0        1           1
# 4        04-01-2018       1   0     1        0        2           1
# 5        05-01-2018       1   0     1        0        3           1
#
#          weathersit       temp     atemp      hum  windspeed  casual  \
# instant
# 1                 2  14.110847  18.18125  80.5833  10.749882     331
# 2                 2  14.902598  17.68695  69.6087  16.652113     131
# 3                 1   8.050924   9.47025  43.7273  16.636703     120
# 4                 1   8.200000  10.60610  59.0435  10.739832     108
# 5                 1   9.305237  11.46350  43.6957  12.522300      82
#
#          registered   cnt
# instant
# 1               654   985
# 2               670   801
# 3              1229  1349
# 4              1454  1562
# 5              1518  1600

# %%
print(f"The dataset has {df_data.shape[0]} rows and {df_data.shape[1]} columns.")
# Out:
# The dataset has 730 rows and 15 columns.

# %%
df_data.describe()
# Out:
#            season          yr        mnth     holiday     weekday  workingday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     2.498630    0.500000    6.526027    0.028767    2.997260    0.683562
# std      1.110184    0.500343    3.450215    0.167266    2.006161    0.465405
# min      1.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000    4.000000    0.000000    1.000000    0.000000
# 50%      3.000000    0.500000    7.000000    0.000000    3.000000    1.000000
# 75%      3.000000    1.000000   10.000000    0.000000    5.000000    1.000000
# max      4.000000    1.000000   12.000000    1.000000    6.000000    1.000000
#
#        weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     1.394521   20.319259   23.726322   62.765175   12.763620
# std      0.544807    7.506729    8.150308   14.237589    5.195841
# min      1.000000    2.424346    3.953480    0.000000    1.500244
# 25%      1.000000   13.811885   16.889713   52.000000    9.041650
# 50%      1.000000   20.465826   24.368225   62.625000   12.125325
# 75%      2.000000   26.880615   30.445775   72.989575   15.625589
# max      3.000000   35.328347   42.044800   97.250000   34.000021
#
#             casual   registered          cnt
# count   730.000000   730.000000   730.000000
# mean    849.249315  3658.757534  4508.006849
# std     686.479875  1559.758728  1936.011647
# min       2.000000    20.000000    22.000000
# 25%     316.250000  2502.250000  3169.750000
# 50%     717.000000  3664.500000  4548.500000
# 75%    1096.500000  4783.250000  5966.000000
# max    3410.000000  6946.000000  8714.000000

# %% [markdown]
# Missing values could be due to several reasons.
# - Human error
# - Privacy issues etc

# %%
df_data.isna().sum()
# Out:
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# No missing values. `Imputation` can be skipped for this dataset.

# %% [markdown]
# #### Introduce categorical names
# Introdcue categorical description columns for Explorartory Data Analysis - Univariate, Bivariate, Mulitvariate analysis.

# %%
# Columns holding numerical data.
NUMERICAL_COLUMNS=['temp','atemp','hum','windspeed']
# Columns holding categorical data.

CATEGORICAL_COLUMNS=['season', 'yr', 'mnth', 'holiday', 'weekday','workingday', 'weathersit']

# Creates category names/description columns for analysis.
category_variable_name_dict = {
   'season': {1:'Spring', 2:'Summer', 3:'Fall', 4:'Winter'},
   'yr' : {0: '2018', 1: '2019'},
   'mnth': { 1 : "January", 2 : "February", 3 : "March", 4 : "April", 5 : "May", 6 : "June", 7 : "July", 8 : "August", 9 : "September", 10 : "October", 11 : "November", 12 : "December"},
   'holiday': {0: 'Holiday', 1: 'Not Holiday'},
   'weekday': {0:'Sunday', 1:'Monday', 2:'Tuesday', 3:'Wednesday', 4:'Thursday', 5:'Friday', 6:'Saturday'},
   'workingday': {0: 'Working Day', 1: 'Not Working Day'},
   'weathersit': {1: 'Clear, Few clouds, Partly cloudy, Partly cloudy', 2: 'Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist',
                  3: 'Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds'}
                  # EXCLUDING as NO RECORDS: 4: 'Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog'}
}

for category in category_variable_name_dict:
   df_data[category + '_name'] = df_data[category].map(category_variable_name_dict[category])

print(list(df_data.columns))
# Out:
# ['dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt', 'season_name', 'yr_name', 'mnth_name', 'holiday_name', 'weekday_name', 'workingday_name', 'weathersit_name']

# %% [markdown]
# ### Univariate Analysis: Numerical Variables
#
# When dealing with numerical variables, we have to check their properties like:
#
# - Mean
# - Median
# - Standard Deviation
# - Kurtosis/skewness
# - distribution/range

# %%
sns.set_style('whitegrid')

for column in NUMERICAL_COLUMNS + ['cnt']:
    fig, axs = plt.subplots(ncols = 3, figsize=(10, 2))
    sns.histplot(df_data, x=column, kde = False, color ='red', bins = 30, ax=axs[0])
    sns.boxplot(df_data, x=column, color ='lightgreen', ax=axs[1])
    sns.violinplot(data=df_data, x=column, ax=axs[2])

# %% [markdown]
# #### Univariate Analysis Summary
# - `Windspeed` has outliers. Should we remove outliers?

# %% [markdown]
# ### Univariate Analysis: Categorical Variables

# %%
import warnings
warnings.filterwarnings("ignore")

fig, axs = plt.subplots(ncols = 7, figsize=(20, 3))
for i, column in enumerate(CATEGORICAL_COLUMNS):
    g = sns.countplot(df_data, x=column, color='lightgreen', ax=axs[i])
    g.set_xticklabels(labels=category_variable_name_dict[column].values(), rotation=90)

# %% [markdown]
# #### Summary of Univariate Analysis of categorical data
# - Holiday
#   - Majority of bike hires are on holidays
#   - This information matches with `Working day or Not working day`
#
# - Season, Month, Week
#   - Consistent bike rents across season, month and week.
#
# - Weather Situation
#    - Less bike hires on snowy or rainy days.

# %% [markdown]
# ### Bivariate Analysis
#
# ![Bivariate Analysis](https://miro.medium.com/v2/resize:fit:845/1*P10xcq7lK2VPp0ENwf6ttw.png "Bivariate Analysis")

# %%
sns.pairplot(data=df_data,
             y_vars=['cnt'],
             x_vars=['temp','atemp','hum','windspeed'])

# %%
for i, column in enumerate(NUMERICAL_COLUMNS):
    fig, axs = plt.subplots(ncols=4, figsize=(15, 3))
    sns.scatterplot(df_data, x=column, y='cnt',  hue="season_name",  ax=axs[0])
    sns.scatterplot(df_data, x=column, y='cnt',  hue="holiday_name",  ax=axs[1])
    sns.scatterplot(df_data, x=column, y='cnt',  hue="workingday_name",  ax=axs[2])
    sns.scatterplot(df_data, x=column, y='cnt',  hue="weekday_name",  ax=axs[3])

# %%
sns.pairplot(data=df_data,
             y_vars=['cnt'],
             x_vars=['season', 'yr', 'mnth', 'holiday', 'weekday','workingday', 'weathersit'],
             kind="reg")

# %% [markdown]
# ### Multicollinearity
#
# Draw Heatmap to check for multicollinearity and relationship between two variables

# %%
sns.heatmap(df_data[NUMERICAL_COLUMNS + CATEGORICAL_COLUMNS].corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #### Feature Engineering
#
# Introdce `Day of Year` feature from `dteday` feature.

# %%
df_data['dteday'] = pd.to_datetime(df_data['dteday'], format='%m-%d-%Y', errors='coerce')
df_data['day_of_year'] = df_data['dteday'].dt.dayofyear

# %% [markdown]
# #### Scaling & Encoding Categorical Variables
#
# - Standardize numerical features by removing the mean and scaling to unit variance.
#
# - Encode Categorical Variable through `One-hot Encoding`
#
# _Dummy Encoding Vs. One hot encoding_:  One hot encoding utilises N binary variables for N categories in a variable. Dummy encoding uses N-1 features to represent N labels/categories.
#
# Linear regressions behave badly when an n-dimensional input doesn't actually range freely across all n dimensions.

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer


numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value=0)),
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))])

column_transformer = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, ['day_of_year', 'yr', 'mnth', 'holiday', 'workingday', 'temp', 'atemp', 'hum', 'windspeed']),
         ('cat', categorical_transformer, ['season', 'weekday', 'weathersit'])]
    )

# %% [markdown]
# #### Feature Selection

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE

y = df_data['cnt']
X = df_data.drop('cnt', axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

column_transformer.set_output(transform='pandas')

# fit the column transformer to the training data
column_transformer.fit(X_train)

# apply the pipeline to the training and test data
X_train_ = column_transformer.transform(X_train)
X_test_ = column_transformer.transform(X_test)

print(X_train_.head(5))
# Out:
#          num__day_of_year   num__yr  num__mnth  num__holiday  num__workingday  \
# instant
# 543             -0.058286  0.996581  -0.172238     -0.173154         0.678233
# 279             -0.058286 -1.003431   0.980619     -0.173154         0.678233
# 118             -0.058286 -1.003431  -0.748666     -0.173154         0.678233
# 706              0.419244  0.996581   1.557047     -0.173154         0.678233
# 103             -0.058286 -1.003431  -0.748666     -0.173154         0.678233
#
#          num__temp  num__atemp  num__hum  num__windspeed  cat__season_1  ...  \
# instant                                                                  ...
# 543       1.092699    1.008417 -1.933550        1.069575            0.0  ...
# 279      -0.019990    0.022849 -0.032523       -0.693323            0.0  ...
# 118       0.654919    0.628225  0.550540        1.702638            0.0  ...
# 706      -0.968517   -0.951042  1.012136       -0.749423            0.0  ...
# 103      -0.466892   -0.365203  1.412992        0.796960            0.0  ...
#
#          cat__weekday_0  cat__weekday_1  cat__weekday_2  cat__weekday_3  \
# instant
# 543                 0.0             0.0             0.0             1.0
# 279                 0.0             0.0             0.0             0.0
# 118                 0.0             0.0             0.0             0.0
# 706                 0.0             0.0             0.0             0.0
# 103                 0.0             0.0             0.0             1.0
#
#          cat__weekday_4  cat__weekday_5  cat__weekday_6  cat__weathersit_1  \
# instant
# 543                 0.0             0.0             0.0                1.0
# 279                 1.0             0.0             0.0                1.0
# 118                 1.0             0.0             0.0                0.0
# 706                 0.0             1.0             0.0                0.0
# 103                 0.0             0.0             0.0                0.0
#
#          cat__weathersit_2  cat__weathersit_3
# instant
# 543                    0.0                0.0
# 279                    0.0                0.0
# 118                    1.0                0.0
# 706                    1.0                0.0
# 103                    1.0                0.0
#
# [5 rows x 23 columns]

# %%
lm = LinearRegression()
lm.fit(X_train_, y_train)
rfe = RFE(lm, n_features_to_select=10)
rfe = rfe.fit(X_train_, y_train)

# %%
list(zip(X_train_.columns,rfe.support_,rfe.ranking_))
# Out:
# [('num__day_of_year', False, 10),
#  ('num__yr', False, 3),
#  ('num__mnth', False, 11),
#  ('num__holiday', False, 2),
#  ('num__workingday', True, 1),
#  ('num__temp', False, 4),
#  ('num__atemp', False, 12),
#  ('num__hum', False, 6),
#  ('num__windspeed', False, 5),
#  ('cat__season_1', True, 1),
#  ('cat__season_2', True, 1),
#  ('cat__season_3', True, 1),
#  ('cat__season_4', True, 1),
#  ('cat__weekday_0', True, 1),
#  ('cat__weekday_1', False, 7),
#  ('cat__weekday_2', False, 14),
#  ('cat__weekday_3', False, 9),
#  ('cat__weekday_4', False, 13),
#  ('cat__weekday_5', False, 8),
#  ('cat__weekday_6', True, 1),
#  ('cat__weathersit_1', True, 1),
#  ('cat__weathersit_2', True, 1),
#  ('cat__weathersit_3', True, 1)]

# %%
X_train_.columns[rfe.support_]
# Out:
# Index(['num__workingday', 'cat__season_1', 'cat__season_2', 'cat__season_3',
#        'cat__season_4', 'cat__weekday_0', 'cat__weekday_6',
#        'cat__weathersit_1', 'cat__weathersit_2', 'cat__weathersit_3'],
#       dtype='object')

# %%
X_train_rfe = X_train_[X_train_.columns[rfe.support_]]
X_train_rfe.head()
# Out:
#          num__workingday  cat__season_1  cat__season_2  cat__season_3  \
# instant
# 543             0.678233            0.0            0.0            1.0
# 279             0.678233            0.0            0.0            0.0
# 118             0.678233            0.0            1.0            0.0
# 706             0.678233            0.0            0.0            0.0
# 103             0.678233            0.0            1.0            0.0
#
#          cat__season_4  cat__weekday_0  cat__weekday_6  cat__weathersit_1  \
# instant
# 543                0.0             0.0             0.0                1.0
# 279                1.0             0.0             0.0                1.0
# 118                0.0             0.0             0.0                0.0
# 706                1.0             0.0             0.0                0.0
# 103                0.0             0.0             0.0                0.0
#
#          cat__weathersit_2  cat__weathersit_3
# instant
# 543                    0.0                0.0
# 279                    0.0                0.0
# 118                    1.0                0.0
# 706                    1.0                0.0
# 103                    1.0                0.0

# %% [markdown]
# #### The variance inflation factor (VIF)
#
# So how do we detect and deal with collinearity? One way is to calculate the variance inflation factor for each feature. The VIF is given by
# VIF𝑖=11−𝑅2𝑖
#
# where 𝑅2
# is the coefficient of determination. It is generally deemed that a feature that has a VIF value greater than 5 is highly collinear with other features in the data.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

VIF             = pd.DataFrame()
VIF['feature']  = X_train_.columns
VIF['VIF']      = [variance_inflation_factor(X_train_.values, i) for i in range(X_train_.shape[1])]
# take a look
VIF
# Out:
#               feature        VIF
# 0    num__day_of_year   1.019497
# 1             num__yr   1.029173
# 2           num__mnth   3.211592
# 3        num__holiday        inf
# 4     num__workingday        inf
# 5           num__temp  63.064194
# 6          num__atemp  58.772285
# 7            num__hum   1.804783
# 8      num__windspeed   1.223541
# 9       cat__season_1        inf
# 10      cat__season_2        inf
# 11      cat__season_3        inf
# 12      cat__season_4        inf
# 13     cat__weekday_0        inf
# 14     cat__weekday_1        inf
# 15     cat__weekday_2        inf
# 16     cat__weekday_3        inf
# 17     cat__weekday_4        inf
# 18     cat__weekday_5        inf
# 19     cat__weekday_6        inf
# 20  cat__weathersit_1        inf
# 21  cat__weathersit_2        inf
# 22  cat__weathersit_3        inf

# %% [markdown]
# we can see that (unsurprisingly) temp and atemp are both features with extremely high collinearity. Now let us see what happens if we drop the atemp column and recalculate the VIF.
#
# TODO: Not sure `weathersit`, `season`, `holiday` are INF. Need to investigate.

# %%
X_train_new = X_train_.drop(['num__atemp'], axis=1)

VIF            = pd.DataFrame()
VIF['feature'] = X_train_new.columns
VIF['VIF']     = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
VIF
# Out:
#               feature       VIF
# 0    num__day_of_year  1.019436
# 1             num__yr  1.028276
# 2           num__mnth  3.209798
# 3        num__holiday       inf
# 4     num__workingday       inf
# 5           num__temp  3.502165
# 6            num__hum  1.797588
# 7      num__windspeed  1.185859
# 8       cat__season_1       inf
# 9       cat__season_2       inf
# 10      cat__season_3       inf
# 11      cat__season_4       inf
# 12     cat__weekday_0       inf
# 13     cat__weekday_1       inf
# 14     cat__weekday_2       inf
# 15     cat__weekday_3       inf
# 16     cat__weekday_4       inf
# 17     cat__weekday_5       inf
# 18     cat__weekday_6       inf
# 19  cat__weathersit_1       inf
# 20  cat__weathersit_2       inf
# 21  cat__weathersit_3       inf

# %% [markdown]
# ### Feature selection by p-value

# %%
# TODO

# %% [markdown]
# ### Build Model

# %%
model = LinearRegression()
model.fit(X_train_, y_train)

y_test_pred = model.predict(X_test_)

print("model score: %.3f" % model.score(X_test_, y_test))
# Out:
# model score: 0.825

# %% [markdown]
# #### Model evaluaiton metrics
#
# R2 scorr is used as evaluation metric.

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_test_pred)
# Out:
# 0.8245604342902266

# %%
print(list(zip(model.coef_, X_train_.columns)))
import numpy as np
coefficients = pd.concat([pd.DataFrame(X_train_.columns, columns=['feature']),pd.DataFrame(np.transpose(model.coef_), columns=['coefficients'])], axis = 1)
print(coefficients.sort_values('coefficients', ascending=False))
# Out:
# [(53.47710658052215, 'num__day_of_year'), (1002.4922548986252, 'num__yr'), (-50.74868052270659, 'num__mnth'), (-67.7241126022227, 'num__holiday'), (68.58414547978668, 'num__workingday'), (951.9906915921497, 'num__temp'), (-36.11663269038613, 'num__atemp'), (-167.70715792724144, 'num__hum'), (-219.75194319044806, 'num__windspeed'), (-922.7901776977617, 'cat__season_1'), (233.37958386928173, 'cat__season_2'), (-44.12281852376121, 'cat__season_3'), (733.5334123522422, 'cat__season_4'), (-278.2160139946146, 'cat__weekday_0'), (-129.1521678812844, 'cat__weekday_1'), (-9.314629913057358, 'cat__weekday_2'), (59.8409052158026, 'cat__weekday_3'), (18.36794489941307, 'cat__weekday_4'), (80.73289052469362, 'cat__weekday_5'), (257.7410711490479, 'cat__weekday_6'), (897.5526567084431, 'cat__weathersit_1'), (423.35723960555134, 'cat__weathersit_2'), (-1320.9098963139945, 'cat__weathersit_3')]
#               feature  coefficients
# 1             num__yr   1002.492255
# 5           num__temp    951.990692
# 20  cat__weathersit_1    897.552657
# 12      cat__season_4    733.533412
# 21  cat__weathersit_2    423.357240
# 19     cat__weekday_6    257.741071
# 10      cat__season_2    233.379584
# 18     cat__weekday_5     80.732891
# 4     num__workingday     68.584145
# 16     cat__weekday_3     59.840905
# 0    num__day_of_year     53.477107
# 17     cat__weekday_4     18.367945
# 15     cat__weekday_2     -9.314630
# 6          num__atemp    -36.116633
# 11      cat__season_3    -44.122819
# 2           num__mnth    -50.748681
# 3        num__holiday    -67.724113
# 14     cat__weekday_1   -129.152168
# 7            num__hum   -167.707158
# 8      num__windspeed   -219.751943
# 13     cat__weekday_0   -278.216014
# 9       cat__season_1   -922.790178
# 22  cat__weathersit_3  -1320.909896
